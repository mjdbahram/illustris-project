# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
def get(path, params=None):
    r = requests.get(path, params=params, headers=headers)
    r.raise_for_status()
    if (r.headers['content-type'] == 'application/json'):
        return r.json()
    
    if ('content-disposition' in r.headers):
        filename = r.headers['content-disposition'].split("filename=")[1]
        with open(filename, 'wb') as f:
            f.write(r.content)
        return filename
    return r

# %%
baseUrl = 'http://www.illustris-project.org/api/'
headers = {"api-key":"79d3daabdc8c4290395780680a4e1107"}

# %%
url = "http://www.illustris-project.org/api/Illustris-1/snapshots/z=0/subhalos/"
subhalos = get(url)
subhalos['count']
# Out:
# 4366546

# %%
# first convert log solar masses into group catalog units
mass_min = 10**11.9 / 1e10 * 0.704
mass_max = 10**12.1 / 1e10 * 0.704

# form the search_query string by hand for once
search_query = "?mass__gt=" + str(mass_min) + "&mass__lt=" + str(mass_max)

# form the url and make the request
url = "http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos" #+ search_query
subhalos = get(url)
subhalos['count']
# Out:
# 4366546

# %%
subhalos
# Out:
# {'count': 4366546,
#  'next': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100',
#  'previous': None,
#  'results': [{'id': 0,
#    'sfr': 2.93449,
#    'mass_log_msun': 14.498287052370081,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/0/'},
#   {'id': 1,
#    'sfr': 0.0147863,
#    'mass_log_msun': 13.498518094447533,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/1/'},
#   {'id': 2,
#    'sfr': 0.951135,
#    'mass_log_msun': 12.910891088644528,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/2/'},
#   {'id': 3,
#    'sfr': 2.34202,
#    'mass_log_msun': 12.56901792642108,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/3/'},
#   {'id': 4,
#    'sfr': 0.273659,
#    'mass_log_msun': 12.598188733397052,
# ...

# %%
subhalos
# Out:
# {'count': 4366546,
#  'next': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100',
#  'previous': None,
#  'results': [{'id': 0,
#    'sfr': 2.93449,
#    'mass_log_msun': 14.498287052370081,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/0/'},
#   {'id': 1,
#    'sfr': 0.0147863,
#    'mass_log_msun': 13.498518094447533,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/1/'},
#   {'id': 2,
#    'sfr': 0.951135,
#    'mass_log_msun': 12.910891088644528,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/2/'},
#   {'id': 3,
#    'sfr': 2.34202,
#    'mass_log_msun': 12.56901792642108,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/3/'},
#   {'id': 4,
#    'sfr': 0.273659,
#    'mass_log_msun': 12.598188733397052,
# ...

# %%
subhalo_coordinate = []
subhalos_base_dir_url = "http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/" 
subhalos_dir_url = subhalos_base_dir_url
subhalos = get(subhalos_base_dir_url)
next_button = subhalos['next']

start_stage = 0
while ( True ):
    for i in range(len(subhalos['results'])):
        print(subhalos['results'][i]['id'])
        subhalo_info = get(subhalos_base_dir_url + str(subhalos['results'][i]['id']))
        #subhalo_coordinate.append([subhalo_info['pos_x'], subhalo_info['pos_y'], subhalo_info['pos_z']])
        print([subhalo_info['pos_x'], subhalo_info['pos_y'], subhalo_info['pos_z']])
    start_stage += len(subhalos['results'])
    
    if ( next_button != None ):
        subhalos_dir_url = subhalos['next']
        subhalos = get(subhalos_dir_url)
        next_button = subhalos['next']
    else :
        break
# Out:
# 0
# [931.088, 26254.3, 18358.9]
# 1
# [186.617, 24647.0, 16910.6]
# 2
# [763.91, 26755.7, 17237.8]
# 3
# [1205.82, 26492.8, 18220.5]
# 4
# [992.408, 26614.7, 17591.2]
# 5
# [865.807, 26523.9, 15511.3]
# 6
# [1522.58, 26560.8, 19467.1]
# 7
# [271.775, 26460.5, 15866.9]
# 8
# [74921.1, 24164.9, 16797.0]
# 9
# [835.328, 26671.5, 17974.5]
# 10
# [1122.91, 26606.1, 18434.3]
# 11
# [808.687, 26290.5, 18199.0]
# 12
# [1425.43, 26676.8, 17299.4]
# 13
# [1613.51, 26050.1, 19822.7]
# 14
# [827.264, 26417.8, 18223.0]
# 15
# [1256.45, 26785.9, 17628.8]
# 16
# [329.423, 26699.2, 19227.8]
# 17
# [1664.64, 25406.8, 18544.5]
# 18
# [724.136, 26407.4, 18167.5]
# 19
# [782.273, 26766.7, 17165.8]
# 20
# [517.726, 25952.2, 18123.5]
# 21
# [434.08, 24638.4, 16832.6]
# 22
# [74974.5, 24108.0, 16472.0]
# 23
# [778.362, 26279.6, 18415.0]
# 24
# [1512.99, 25558.5, 18344.1]
# 25
# [1165.61, 25946.1, 18561.8]
# 26
# [1753.28, 26010.0, 16639.9]
# 27
# [944.774, 25424.8, 19290.5]
# 28
# ...

# %%
subhalo_coordinate = []
subhalos_dir_url = "http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/" 
subhalos = get(subhalos_dir_url)




for i in range(subhalos['count']):
    print(i)
    subhalo_info = get(subhalos_dir_url + str(i))
    #subhalo_coordinate.append([subhalo_info['pos_x'], subhalo_info['pos_y'], subhalo_info['pos_z']])
    print([subhalo_info['pos_x'], subhalo_info['pos_y'], subhalo_info['pos_z']])
# Out:
# 0
# [931.088, 26254.3, 18358.9]
# 1
# [186.617, 24647.0, 16910.6]
# 2
# [763.91, 26755.7, 17237.8]
# 3
# [1205.82, 26492.8, 18220.5]
# 4
# [992.408, 26614.7, 17591.2]
# 5
# [865.807, 26523.9, 15511.3]
# 6
# [1522.58, 26560.8, 19467.1]
# 7
# [271.775, 26460.5, 15866.9]
# 8
# [74921.1, 24164.9, 16797.0]
# 9
# [835.328, 26671.5, 17974.5]
# 10
# [1122.91, 26606.1, 18434.3]
# 11
# [808.687, 26290.5, 18199.0]
# 12
# [1425.43, 26676.8, 17299.4]
# 13
# [1613.51, 26050.1, 19822.7]
# 14
# [827.264, 26417.8, 18223.0]
# 15
# [1256.45, 26785.9, 17628.8]
# 16
# [329.423, 26699.2, 19227.8]
# 17
# [1664.64, 25406.8, 18544.5]
# 18
# [724.136, 26407.4, 18167.5]
# 19
# [782.273, 26766.7, 17165.8]
# 20
# [517.726, 25952.2, 18123.5]
# 21
# [434.08, 24638.4, 16832.6]
# 22
# [74974.5, 24108.0, 16472.0]
# 23
# [778.362, 26279.6, 18415.0]
# 24
# [1512.99, 25558.5, 18344.1]
# 25
# [1165.61, 25946.1, 18561.8]
# 26
# [1753.28, 26010.0, 16639.9]
# 27
# [944.774, 25424.8, 19290.5]
# 28
# ...

# %%
subhalos['count']
# Out:
# 4366546

# %%
subhalos_dir_url
# Out:
# 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100'

# %%
subhalos = get(subhalos_dir_url)

# %%
str(subhalos['results'][2]['id'])
# Out:
# '102'

# %%
subhalos_dir_url + str(subhalos['results'][i]['id'])
# Out:
# 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100100'

# %%
subhalo_info = get(subhalos_dir_url + str(subhalos['results'][0]['id']))
        #subhalo_coordinate.append([subhalo_info['pos_x'], subhalo_info['pos_y'], subhalo_info['pos_z']])
subhalo_info
# Out:
# {'count': 4366546,
#  'next': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100200',
#  'previous': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100000',
#  'results': [{'id': 100100,
#    'sfr': 0.0,
#    'mass_log_msun': 9.13918564312832,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/100100/'},
#   {'id': 100101,
#    'sfr': 0.0,
#    'mass_log_msun': 9.13918564312832,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/100101/'},
#   {'id': 100102,
#    'sfr': 0.0,
#    'mass_log_msun': 9.12198768336633,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/100102/'},
#   {'id': 100103,
#    'sfr': 0.0,
#    'mass_log_msun': 9.13918564312832,
#    'url': 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/100103/'},
#   {'id': 100104,
#    'sfr': 0.0,
# ...

# %%
subhalos['next']
# Out:
# 'http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=200'

# %%
{
    "count": 4366546,
    "next": "http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100",
    "previous": null}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-65b12105fd66> in <module>
#       2     "count": 4366546,
#       3     "next": "http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/?limit=100&offset=100",
# ----> 4     "previous": null}
#
# NameError: name 'null' is not defined

# %%
    sub_prog = get(url)
    sub_halo.append([sub_prog['pos_x'], sub_prog['pos_y'], sub_prog['pos_z']])

# %%
sub_halo
# Out:
# [[808.687, 26290.5, 18199.0],
#  [827.264, 26417.8, 18223.0],
#  [1256.45, 26785.9, 17628.8],
#  [74974.5, 24108.0, 16472.0],
#  [19692.1, 48368.9, 48719.6],
#  [20821.8, 48652.6, 49650.4],
#  [21232.5, 48927.0, 48827.4],
#  [11333.0, 51048.2, 47560.6],
#  [11695.5, 51455.6, 46794.3],
#  [10422.9, 51024.3, 48540.2],
#  [10240.6, 50788.2, 47207.8],
#  [68759.8, 58586.3, 53988.8],
#  [67014.0, 60296.3, 54149.0],
#  [66980.6, 59749.7, 53943.5],
#  [67256.7, 56604.4, 53634.7],
#  [73907.7, 17753.4, 24528.9],
#  [43445.1, 38352.5, 70032.4],
#  [41883.5, 66458.7, 42624.0],
#  [40030.9, 66613.3, 42614.3],
#  [40194.0, 66281.1, 44267.7],
#  [37229.4, 1048.15, 69939.0],
#  [33011.6, 849.995, 71033.6],
#  [24520.4, 32111.2, 40991.4],
#  [18853.3, 68716.1, 2959.29],
#  [18172.1, 67665.8, 2635.22],
#  [18446.0, 67196.6, 3048.14],
#  [18248.2, 69564.7, 2387.73],
#  [58393.4, 395.094, 37937.6],
#  [57376.2, 581.101, 38151.0],
#  [59021.1, 1579.7, 38254.8],
#  [58990.2, 719.616, 37398.8],
# ...
